# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.
# and David Edel
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.

"""Simple example of QAT using DDP (ResNet on CIFAR-10)
Adapted from https://github.com/akamaster/pytorch_resnet_cifar10"""
# os.environ["TORCH_LOGS"]="recompiles"
import torch
import torch._dynamo

torch._dynamo.config.cache_size_limit = 64
torch._dynamo.config.recompile_limit = 64
# torch._dynamo.config.verbose = True
# torch._inductor.config.debug = True

import json
import torch.nn as nn
from torchvision import transforms as T
from torch import optim

import itertools

from model import resnet
from model.resnet import ResNet,BasicBlock
import wandb
import time


from tqpmod.parq_utils import (
    NORM_LAYERS,
    get_param_groups,
    split_param_groups,
    create_data_loaders,
)
from tqpmod.tqp_optimizer_scale_train import TQPS
# from tqpmod.softbinning import SoftBinning # replace with custom
from tqpmod.logging_utils import init_loger_and_folder
# from tqpmod.train_eval import train_epoch, evaluate

import math # for nan check

DEVICE = torch.device("cuda")
# torch.set_float32_matmul_precision("high")  # improves matmul speed
import matplotlib.pyplot as plt

# %%
class SoftBinningScale:
    def __init__(self, bins=3):
        if bins < 3 or bins % 2 != 1:
            raise ValueError("bins must be odd >= 3")
        self.bins = bins // 2
        self.max = self.bins

    @torch.no_grad()
    @torch.compile()
    def call_test(self, x: torch.Tensor):
        x = torch.abs(x)
        y = 1 - self.max + x
        mask = x < self.max
        y[mask] = x[mask] - torch.floor(x[mask])
        y = y * torch.abs(1 - y)
        return y

    def compute_xright_quantile(self, x: torch.Tensor):
        x, _ = x.clone().detach().flatten().sort()
        third = x[x.shape[0] // 3]
        two_thirds = x[int(x.shape[0] * (2 / 3))]
        return third.abs() + two_thirds.abs()


soft_binning = SoftBinningScale(3)

# %%
@torch.compile()
@torch.no_grad()
def calc_reg_loss_scale_layer(
    optimizer:TQPS,
    soft_binning: SoftBinningScale,
    n_params,
    device=torch.device("cuda:0"),
    M=1,
    beta=5e-4,
    compute_per_layer_share_done = False
):
    """
    returns tuple of:
    avg_reg_loss, a norm, %done
    """

    reg_loss = torch.zeros((), device=device, requires_grad=False)
    quantized_params = torch.zeros(
        (), device=device, requires_grad=False, dtype=torch.int64
    )
    norm = torch.zeros((), device=device, requires_grad=False)
    per_layer_share_done = torch.zeros((len(optimizer.regularized_params)))
    for i, param in enumerate(optimizer.regularized_params):
        
        reg_loss += soft_binning.call_test(param).sum().detach()

        calc_param = param.detach()
        quantized_this_param = (
            (abs(calc_param - calc_param.round().clip(-M, M)) < (beta / 2))
            .sum()
            .to(torch.int64))
        quantized_params += quantized_this_param
        
        per_layer_share_done[i] = quantized_this_param / param.numel()
        norm += param.norm().detach()

    return (reg_loss / n_params).item(), norm.sqrt().item(), (quantized_params / n_params).item(), per_layer_share_done

# %%
@torch.no_grad()
def factor_function_test(params):
    return (params.flatten().std() * 2 * 0.5) * torch.ones((params.shape[0],),device=params.device)
    # the 0.5 and 2 cancel, but leave them in because we could adjust the params for this

# %%
x = torch.linspace(-3.5,3.5,1000)
fac = factor_function_test(x)
plt.hist(x / fac)
# Out:
# (array([100., 100., 100., 100., 100., 100., 100., 100., 100., 100.]),
#  array([-1.72945428, -1.3835634 , -1.03767252, -0.69178176, -0.34589088,
#          0.        ,  0.34589076,  0.69178176,  1.03767252,  1.38356328,
#          1.72945428]),
#  <BarContainer object of 10 artists>)

# %%
# Training function
from tqdm import tqdm


def train_epoch(model, loader, criterion, optimizer, scaler, device, trace=False, epoch = None,amp=False):
    model.train()
    running_loss = torch.zeros((), device=device)
    correct = torch.zeros((), device=device)
    total = 0  # cpu side, because we add ints to it (from shape) which are already on cpu and dont need to sync with the gpu

    pbar = tqdm(loader, desc="Training")
   
    for images, labels in pbar:

        torch.compiler.cudagraph_mark_step_begin()
        images: torch.Tensor
        labels: torch.Tensor
        images, labels = images.to(device, non_blocking=True), labels.to(
            device, non_blocking=True
        )


        # Mixed precision training
        optimizer.base_optimizer.zero_grad()
        with torch.amp.autocast("cuda",enabled=amp):
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        #loss.backward()
        #optimizer.step()

        with torch.no_grad():
            running_loss += loss.detach()
            _, predicted = outputs.max(1)
            correct += predicted.eq(labels).sum().detach()
            total += labels.size(0)


    avg_loss = running_loss.item() / len(loader)
    avg_accuracy = 100.0 * correct.item() / total
    #logger.info(f"loss {avg_loss:.4f}   acc {avg_accuracy:.2f}%")
    return avg_loss, avg_accuracy

@torch.no_grad()
def clip_round_model(model:nn.Module):
    for name, param in model.named_parameters():
        if "weight" in name and len(param.shape) >= 2:
            #print(name,param.shape)
            param.clip_(-1,1).round_()

# Evaluation function
@torch.no_grad()
def evaluate(model:nn.Module, model_clone:nn.Module, loader, criterion, device,transform_train_x_dtype = torch.float32, amp=False):
    model.eval()

    running_loss = torch.zeros((), device=device, requires_grad=False)
    correct = torch.zeros((), device=device, requires_grad=False)

    running_loss_clone = torch.zeros((), device=device, requires_grad=False)
    correct_clone = torch.zeros((), device=device, requires_grad=False)

    total = 0

    model_clone.load_state_dict(model.state_dict())
    clip_round_model(model_clone)
    model_clone.eval()

    pbar = tqdm(loader, desc="Evaluating")
    for images, labels in pbar:
        torch.compiler.cudagraph_mark_step_begin() # probably not needed
        images: torch.Tensor
        labels: torch.Tensor
        images, labels = images.to(device,transform_train_x_dtype, non_blocking=True), labels.to(
            device, non_blocking=True
        )
        with torch.amp.autocast("cuda",enabled=amp):
            outputs = model(images)
            outputs_clone = model_clone(images)
            loss = criterion(outputs, labels)
            loss_clone = criterion(outputs_clone,labels)

        running_loss += loss.detach()
        _, predicted = outputs.max(1)
        correct += predicted.eq(labels).sum().detach()

        running_loss_clone += loss_clone.detach()
        _, predicted_clone = outputs_clone.max(1)
        correct_clone += predicted_clone.eq(labels).sum().detach()
        total += labels.size(0)

    avg_loss = running_loss.item() / len(loader)
    test_accuracy = 100.0 * correct.item() / total
    return avg_loss, test_accuracy, running_loss_clone.item() / len(loader), 100.0 * correct_clone.item() / total

# %%
import numpy as np
num_epochs = 100
lr_warmup_epochs = 10
num_epochs_lr_schedule = 99
new_cos_epoch = 55
def get_lr_factor(epoch):
    if epoch < lr_warmup_epochs:
        return (epoch + 1) / lr_warmup_epochs
    elif epoch > num_epochs_lr_schedule:
        return get_lr_factor(num_epochs_lr_schedule)
    else:
        return max(
            [
                0.5
                * (
                    1
                    + np.cos(
                        np.pi
                        * (epoch - lr_warmup_epochs)
                        / (num_epochs_lr_schedule - lr_warmup_epochs)
                    )
                ) ,
                1e-9,
            ]
        )

percentage_new_cos = 0.01

def get_lr_factor_double_cos(epoch):
    if epoch < lr_warmup_epochs:
        return (epoch + 1) / lr_warmup_epochs
    elif epoch < new_cos_epoch:
        return max(
            [
                ( 0.5
                * (
                    1
                    + np.cos(
                        np.pi
                        * (epoch - lr_warmup_epochs)
                        / (new_cos_epoch - lr_warmup_epochs)
                    )
                ) ) * (1 - percentage_new_cos) + percentage_new_cos,
                1e-9,
            ]
        )
    else:
        return 0.5 * percentage_new_cos * (1 + np.cos(np.pi * (epoch-new_cos_epoch)/ (num_epochs - new_cos_epoch) ))
            
x = np.arange(100)
y = [get_lr_factor(xi) for xi in x]
y_new = [get_lr_factor_double_cos(xi) for xi in x]
plt.plot(x,y,label="old")
plt.plot(x,y_new,label="new")
plt.legend()

# %%
from tqpmod.model_utils import inject_scale_layers, rebalance_layers
from typing import Any, Callable


def longrun_scale_layer(
    beta, train_params: dict[str, Any], run_name: str = "ScaleLayerTrain"
):
    #try:
    if True:
        logger, folder = init_loger_and_folder(run_name)
        history = {
            "train_loss": [],
            "train_acc": [],
            "test_loss": [],
            "test_acc": [],
            "reg_loss": [],
            "norm": [],
            "per_layer_share_done": [],
            "beta": [],
        }

        # ALL these hyperparams could get overwritten by train_params
        num_epochs = 600  # 1000  # like 310
        num_epochs_lr_schedule = 599  # 999 # 300
        learning_rate = 0.1
        weight_decay = 2e-4

        lr_warmup_epochs = 10
        percentage_new_cos = 0.1
        new_cos_epoch = (num_epochs - lr_warmup_epochs) / 2  # gets overwritten below

        REG_wait_epochs = 55  # 55

        SEED = torch.randint(0, 10000, (1,))
        batch_size = 64

        inject_scales = True

        if train_params is not None:
            num_epochs = train_params.get("num_epochs", num_epochs)
            num_epochs_lr_schedule = num_epochs - 1
            num_epochs_lr_schedule = train_params.get(
                "num_epochs_lr_schedule", num_epochs_lr_schedule
            )
            learning_rate = train_params.get("learning_rate", learning_rate)
            weight_decay = train_params.get("weight_decay", weight_decay)
            lr_warmup_epochs = train_params.get("lr_warmup_epochs", lr_warmup_epochs)
            percentage_new_cos = train_params.get(
                "percentage_new_cos", percentage_new_cos
            )
            new_cos_epoch = (
                num_epochs - lr_warmup_epochs
            ) / 2  # Overwrite default based on provided params
            new_cos_epoch = train_params.get("new_cos_epoch", new_cos_epoch)
            REG_wait_epochs = train_params.get("REG_wait_epochs", REG_wait_epochs)
            SEED = train_params.get("SEED", SEED)

            batch_size = train_params.get("batch_size", batch_size)

            inject_scales = train_params.get("inject_scales", inject_scales)

        torch.manual_seed(SEED)

        train_loader, val_loader = create_data_loaders(
            "~/data",
            batch_size,
            9,
            False,
            SEED,
        )
        steps_per_epoch = len(train_loader)

        # define loss function (criterion) and optimizer
        scaler = torch.amp.GradScaler("cuda")
        label_smoothing = 0.1
        criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing).to(DEVICE)  #
        model = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
        quant_model = ResNet(BasicBlock,[3,3,3])

        param_groups = []
        # TOD:
        rest_group = []
        names = {
            param: name for name, param in model.named_parameters()
        }  # for debugging

        if inject_scales:
            inject_scale_layers(
                model,
                param_groups,
                factor_function=factor_function_test,
                learning_rate=learning_rate,
                weight_decay=weight_decay,
                scale_grad=True,
            )
            inject_scale_layers(quant_model,[])
        else: # disables scale train
            param_groups.append(
                {
                    "params": [param for param in model.parameters() if len(param.shape) > 1],
                    "quant_bits": 32,
                    "weight_decay": weight_decay,
                    "learning_rate": learning_rate,
                }
            )

        model = model.to(DEVICE)
        quant_model = quant_model.to(DEVICE)
        quant_model.eval()
        # specify number of quantization bits for different parameter groups

        # None indicates that it will need to get updated before starting training
        # param_groups_quant = [{"params:":[param],"quant_bits":0,"weight_decay": None,learning_rate:None} for param in params_quant]
        param_groups_list = []
        for param_group in param_groups:
            param_groups_list.extend([id(param) for param in param_group["params"]])

        for name, param in model.named_parameters():
            if id(param) not in param_groups_list:
                rest_group.append(param)
        param_groups.append(
            {
                "params": rest_group,
                "weight_decay": 0,
                "lr": learning_rate,
            }  # use defalut lr
        )

        def build_lr_factor(lr_warmup_epochs, num_epochs_lr_schedule=None):
            num_epochs_lr_schedule = num_epochs_lr_schedule or (num_epochs - 1)

            def get_lr_factor(epoch):
                if epoch < lr_warmup_epochs:
                    return (epoch + 1) / lr_warmup_epochs
                elif epoch > num_epochs_lr_schedule:
                    return get_lr_factor(num_epochs_lr_schedule)
                else:
                    return max(
                        [
                            0.5
                            * (
                                1
                                + np.cos(
                                    np.pi
                                    * (epoch - lr_warmup_epochs)
                                    / (num_epochs_lr_schedule - lr_warmup_epochs)
                                )
                            ),
                            1e-9,
                        ]
                    )

            return get_lr_factor

        get_lr_factor: Callable = build_lr_factor(
            lr_warmup_epochs, num_epochs_lr_schedule
        )

        def build_lr_double_cos(
            lr_warmup_epochs, num_epochs_lr_schedule, new_cos_epoch, percentage_new_cos
        ):
            def get_lr_factor_double_cos(epoch):
                # test for quant
                if epoch < lr_warmup_epochs:
                    return (epoch + 1) / lr_warmup_epochs
                elif epoch < new_cos_epoch:
                    return max(
                        [
                            (
                                0.5
                                * (
                                    1
                                    + np.cos(
                                        np.pi
                                        * (epoch - lr_warmup_epochs)
                                        / (new_cos_epoch - lr_warmup_epochs)
                                    )
                                )
                            )
                            * (1 - percentage_new_cos)
                            + percentage_new_cos,
                            1e-9,
                        ]
                    )
                else:
                    return (
                        0.5
                        * percentage_new_cos
                        * (
                            1
                            + np.cos(
                                np.pi
                                * (epoch - new_cos_epoch)
                                / (num_epochs_lr_schedule - new_cos_epoch)
                            )
                        )
                    )

            return get_lr_factor_double_cos

        get_lr_factor_double_cos: Callable = build_lr_double_cos(
            lr_warmup_epochs, num_epochs_lr_schedule, new_cos_epoch, percentage_new_cos
        )

        base_optimizer = torch.optim.SGD(
            param_groups,
            learning_rate,
            momentum=0.9,
            weight_decay=weight_decay,
            fused=True,  # test
        )
        lr_scheduler = optim.lr_scheduler.LambdaLR(
            base_optimizer, lr_lambda=get_lr_factor
        )

        best_acc = 0.0
        best_reg_loss = float("inf")

        optimizer = TQPS(
            base_optimizer,
            len(train_loader),
            reg_wait_epochs=REG_wait_epochs,
            regularization_epochs=num_epochs,
            beta=beta,
            device=DEVICE,
            logger=logger,
        )
        optimizer.base_optimizer.zero_grad()

        n_reg_params = sum([torch.numel(x) for x in optimizer.regularized_params])
        model = torch.compile(model, mode="max-autotune", fullgraph=True, dynamic=False)
        quant_model = torch.compile(quant_model)
        torch.save(
            {
                "epoch": 0,
                "num_epochs": num_epochs,
                "SEED": SEED,
                "label_smoothing": label_smoothing,
                "REG_wait_epochs": REG_wait_epochs,
                "lr_warmup_epochs": lr_warmup_epochs,
                "num_epochs_lr_schedule": num_epochs_lr_schedule,
                "model_state_dict": model.state_dict(),
                "base_optimizer_state_dict": base_optimizer.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "current_acc": 0,
                "reg_loss": torch.inf,
                "lr_schedule": lr_scheduler.state_dict(),
                #"scaler": scaler.state_dict(),
                "history": json.dumps(history),
                "best_reg_loss": best_reg_loss,
                "best_acc": best_acc,
                "batch_size": batch_size,
            },
            f"{folder}/init_pre_train.pth",
        )
        with wandb.init(
            project="ResNet-TQP",
            name=f"{run_name}-{beta}",
            config={
                "architecture": "ResNet20",
                "load_state": False,
                "Use Pretrained": f"{False}",
                "dataset": "CIFAR-10",
                "seed": SEED,
                "num_epochs": num_epochs,
                "batch_size": batch_size,
                "optimizer": base_optimizer.__class__.__name__,
                "start_lr": learning_rate,
                "lr_warmup_epochs": lr_warmup_epochs,
                "weight_decay": weight_decay,
                "beta": beta,
                "reg_wait_epochs": REG_wait_epochs,
                "label_smoothing": label_smoothing,
                "note": "every epoch factor, dont wait",
            },
            # mode="disabled"
        ) as run:

            for epoch in range(0, num_epochs):
                # for epoch in range(start_epoch, 350):
                # for epoch in range(num_epochs, num_epochs+20):
                start_time = time.time()
                logger.info(
                    f"\nEpoch [{epoch+1}/{num_epochs}] | LR: {base_optimizer.param_groups[0]['lr']:.10f}"
                )

                if epoch == num_epochs - 1:
                    optimizer.set_final_beta()
                    logger.warning("DISABLED GRAD ON REG-PARAMS")
                    logger.info("overwrote beta to 1 for final epoch")

                # Train
                train_loss, train_acc = train_epoch(
                    model,
                    train_loader,
                    criterion,
                    optimizer,
                    scaler,#scaler,
                    DEVICE,
                    epoch == 10,
                    epoch,
                    amp=True,
                )
                # TODO: compute change rate

                # keep REBALANCE_LAYERS and LR_SCHEDULER.STEP together, because we need to avoid training after rebalancing before updating learning rates
                if epoch == REG_wait_epochs - 1:  # TODO: check one off error
                    param_dict = {
                        group["params"][0]: {"index": index, "group": group}
                        for index, group in enumerate(optimizer.param_groups)
                        if len(group["params"]) == 1
                    }
                    # param_dict is needed because rebalance needs to know each parameter_groups index in the lr_schedulers base_lrs list.
                    # the group itself is also needed to adjust weight decay.
                    rebalance_layers(
                        model,
                        param_dict,
                        lr_scheduler,
                        optimizer,
                        dtype_calc=torch.float32,
                        factor_function=factor_function_test,
                    )
                lr_scheduler.step()

                # TODO: think about wd decay with scaled again!!
                # for param_group in optimizer.get_regularized_param_groups():
                #     param_group["weight_decay"] = weight_decay * get_lr_factor(epoch)

                reg_loss, norm, share_done,per_layer_share_done = calc_reg_loss_scale_layer(
                    optimizer, soft_binning, n_reg_params, beta=beta,device=DEVICE
                )
                # decay beta based on finished_rate
                if epoch > 11 and optimizer.beta != 1.0:
                    new_beta = (1 - share_done) * beta + share_done * (beta * 1e-2)
                    new_beta = min(new_beta, history["beta"][-1])
                    if isinstance(optimizer.beta, torch.Tensor):
                        optimizer.beta.copy_(new_beta)
                    else:
                        optimizer.beta = torch.tensor(
                            new_beta, device=DEVICE, requires_grad=False
                        )
                else:
                    new_beta = beta
                # Save history
                history["beta"].append(new_beta)
                history["train_loss"].append(train_loss)
                history["train_acc"].append(train_acc)

                history["per_layer_share_done"].append(per_layer_share_done.detach().cpu().numpy().tolist())
                logger.info(
                    f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Reg Loss: {reg_loss:.4f}"
                )

                history["reg_loss"].append(reg_loss)
                history["norm"].append(norm)

                to_log = {
                    "lr": torch.tensor(lr_scheduler.get_last_lr()).mean().item(),
                    "epoch": epoch,
                    "train_loss": train_loss,
                    "train_acc": train_acc,
                    "reg_loss": reg_loss,
                    "norm": norm,
                    "beta": optimizer.beta,
                    "share_done": share_done,
                }

                #if epoch % 2 == 1:
                if True:
                    test_loss, test_acc,quant_loss,quant_acc = evaluate(model,quant_model, val_loader, criterion, DEVICE,amp=True)
                    history["test_acc"].append(test_acc)
                    history["test_loss"].append(test_loss)
                    logger.info(
                        f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%"
                    )
                    to_log.update(
                        {
                            "test_loss": test_loss,
                            "test_acc": test_acc,
                            "quant_loss":quant_loss,
                            "quant_acc":quant_acc,
                        }
                    )
                    best_acc = max([test_acc, best_acc])

                    # to_log.update({f"change_rate_layer_{i}": cr for i, cr in enumerate(change_rates)})

                    # Save best model
                    if reg_loss < best_reg_loss:
                        best_reg_loss = reg_loss
                        torch.save(
                            {
                                "epoch": epoch,
                                "num_epochs": num_epochs,
                                "SEED": SEED,
                                "label_smoothing": label_smoothing,
                                "REG_wait_epochs": REG_wait_epochs,
                                "lr_warmup_epochs": lr_warmup_epochs,
                                "num_epochs_lr_schedule": num_epochs_lr_schedule,
                                "model_state_dict": model.state_dict(),
                                "base_optimizer_state_dict": base_optimizer.state_dict(),
                                "optimizer_state_dict": optimizer.state_dict(),
                                "current_acc": test_acc,
                                "reg_loss": reg_loss,
                                "lr_schedule": lr_scheduler.state_dict(),
                                #"scaler": scaler.state_dict(),
                                "history": json.dumps(history),
                                "best_reg_loss": best_reg_loss,
                                "best_acc": best_acc,
                                "batch_size": batch_size,
                            },
                            f"{folder}/best_reg_loss_model.pth",
                        )
                        logger.info(
                            f"✓ Saved best model with best reg_loss: {best_reg_loss:.3f}, accuracy: {test_acc:.2f}%"
                        )
                    else:
                        logger.info(
                            f"(X) model did not beat reg_loss: {reg_loss:.3f} vs {best_reg_loss:.3f}, accuracy: {test_acc:.2f}%"
                        )
                    # health check:
                    if math.isnan(reg_loss):
                        raise RuntimeError("idk why but reg loss in nan")
                epoch_time = time.time() - start_time
                logger.info(f"Epoch Time: {epoch_time:.2f}s")
                to_log.update({"epoch time:": epoch_time})
                run.log(to_log, step=epoch)
            # wandb context
            # if epoch == 10:
            #     break
    #except KeyboardInterrupt as e:
    #    logger.error(f"error: {e}")
    return history, model, optimizer

# %%
hist, model, optimizer = longrun_scale_layer(
    1e-4, {"num_epochs": 300, "REG_wait_epochs": 20}, "100_quant_scores"
)
# Out:
# 2026-06-29 17:35:03 [WARNING] Starting logging...
# /home/david/miniconda3/envs/torch26/lib/python3.14/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/home/david/dev/quantization-thesis/TQP/wandb/run-20260629_173506-4uqfegwg</code>
# Syncing run <strong><a href='https://wandb.ai/david-edel-university-heidelberg-germany/ResNet-TQP/runs/4uqfegwg' target="_blank">100_quant_scores-0.0001</a></strong> to <a href='https://wandb.ai/david-edel-university-heidelberg-germany/ResNet-TQP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/david-edel-university-heidelberg-germany/ResNet-TQP' target="_blank">https://wandb.ai/david-edel-university-heidelberg-germany/ResNet-TQP</a>
#  View run at <a href='https://wandb.ai/david-edel-university-heidelberg-germany/ResNet-TQP/runs/4uqfegwg' target="_blank">https://wandb.ai/david-edel-university-heidelberg-germany/ResNet-TQP/runs/4uqfegwg</a>
# 2026-06-29 17:35:07 [INFO]
# Epoch [1/300] | LR: 0.8414437175
# Training: 100%|██████████| 781/781 [00:28<00:00, 27.11it/s]
# 2026-06-29 17:35:37 [INFO] Train Loss: 1.7785 | Train Acc: 40.33% | Reg Loss: 0.4004
# Evaluating: 100%|██████████| 157/157 [00:07<00:00, 19.73it/s]
# 2026-06-29 17:35:45 [INFO] Test Loss: 1.5413 | Test Acc: 54.42%
# 2026-06-29 17:35:45 [INFO] ✓ Saved best model with best reg_loss: 0.400, accuracy: 54.42%
# 2026-06-29 17:35:45 [INFO] Epoch Time: 37.64s
# 2026-06-29 17:35:45 [INFO]
# Epoch [2/300] | LR: 1.6828874350
# Training: 100%|██████████| 781/781 [00:07<00:00, 102.25it/s]
# 2026-06-29 17:35:53 [INFO] Train Loss: 1.4800 | Train Acc: 56.88% | Reg Loss: 0.6129
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.41it/s]
# 2026-06-29 17:35:54 [INFO] Test Loss: 1.3827 | Test Acc: 64.37%
# 2026-06-29 17:35:54 [INFO] (X) model did not beat reg_loss: 0.613 vs 0.400, accuracy: 64.37%
# 2026-06-29 17:35:54 [INFO] Epoch Time: 8.85s
# 2026-06-29 17:35:54 [INFO]
# Epoch [3/300] | LR: 2.5243313313
# Training: 100%|██████████| 781/781 [00:07<00:00, 102.43it/s]
# 2026-06-29 17:36:01 [INFO] Train Loss: 1.2812 | Train Acc: 66.38% | Reg Loss: 0.9140
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 145.28it/s]
# 2026-06-29 17:36:03 [INFO] Test Loss: 1.2149 | Test Acc: 71.61%
# 2026-06-29 17:36:03 [INFO] (X) model did not beat reg_loss: 0.914 vs 0.400, accuracy: 71.61%
# 2026-06-29 17:36:03 [INFO] Epoch Time: 8.91s
# 2026-06-29 17:36:03 [INFO]
# Epoch [4/300] | LR: 3.3657748699
# Training: 100%|██████████| 781/781 [00:07<00:00, 102.63it/s]
# 2026-06-29 17:36:10 [INFO] Train Loss: 1.1650 | Train Acc: 71.77% | Reg Loss: 1.3030
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.71it/s]
# 2026-06-29 17:36:12 [INFO] Test Loss: 1.2098 | Test Acc: 73.50%
# 2026-06-29 17:36:12 [INFO] (X) model did not beat reg_loss: 1.303 vs 0.400, accuracy: 73.50%
# 2026-06-29 17:36:12 [INFO] Epoch Time: 8.99s
# 2026-06-29 17:36:12 [INFO]
# Epoch [5/300] | LR: 4.2072186470
# Training: 100%|██████████| 781/781 [00:07<00:00, 101.99it/s]
# 2026-06-29 17:36:19 [INFO] Train Loss: 1.1007 | Train Acc: 74.83% | Reg Loss: 1.7407
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.74it/s]
# 2026-06-29 17:36:21 [INFO] Test Loss: 1.1262 | Test Acc: 74.63%
# 2026-06-29 17:36:21 [INFO] (X) model did not beat reg_loss: 1.741 vs 0.400, accuracy: 74.63%
# 2026-06-29 17:36:21 [INFO] Epoch Time: 8.95s
# 2026-06-29 17:36:21 [INFO]
# Epoch [6/300] | LR: 5.0486626625
# Training: 100%|██████████| 781/781 [00:07<00:00, 101.62it/s]
# 2026-06-29 17:36:28 [INFO] Train Loss: 1.0624 | Train Acc: 76.57% | Reg Loss: 2.2179
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.43it/s]
# 2026-06-29 17:36:30 [INFO] Test Loss: 1.0519 | Test Acc: 77.47%
# 2026-06-29 17:36:30 [INFO] (X) model did not beat reg_loss: 2.218 vs 0.400, accuracy: 77.47%
# 2026-06-29 17:36:30 [INFO] Epoch Time: 9.06s
# 2026-06-29 17:36:30 [INFO]
# Epoch [7/300] | LR: 5.8901062012
# Training: 100%|██████████| 781/781 [00:07<00:00, 101.33it/s]
# 2026-06-29 17:36:37 [INFO] Train Loss: 1.0420 | Train Acc: 77.69% | Reg Loss: 2.7277
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.61it/s]
# 2026-06-29 17:36:39 [INFO] Test Loss: 1.0791 | Test Acc: 76.37%
# 2026-06-29 17:36:39 [INFO] (X) model did not beat reg_loss: 2.728 vs 0.400, accuracy: 76.37%
# 2026-06-29 17:36:39 [INFO] Epoch Time: 9.00s
# 2026-06-29 17:36:39 [INFO]
# Epoch [8/300] | LR: 6.7315497398
# Training: 100%|██████████| 781/781 [00:07<00:00, 101.57it/s]
# 2026-06-29 17:36:47 [INFO] Train Loss: 1.0296 | Train Acc: 78.22% | Reg Loss: 3.2568
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.45it/s]
# 2026-06-29 17:36:48 [INFO] Test Loss: 1.1002 | Test Acc: 75.87%
# 2026-06-29 17:36:48 [INFO] (X) model did not beat reg_loss: 3.257 vs 0.400, accuracy: 75.87%
# 2026-06-29 17:36:48 [INFO] Epoch Time: 9.06s
# 2026-06-29 17:36:48 [INFO]
# Epoch [9/300] | LR: 7.5729932785
# Training: 100%|██████████| 781/781 [00:07<00:00, 101.09it/s]
# 2026-06-29 17:36:56 [INFO] Train Loss: 1.0140 | Train Acc: 79.25% | Reg Loss: 3.7474
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.22it/s]
# 2026-06-29 17:36:57 [INFO] Test Loss: 1.1623 | Test Acc: 75.20%
# 2026-06-29 17:36:57 [INFO] (X) model did not beat reg_loss: 3.747 vs 0.400, accuracy: 75.20%
# 2026-06-29 17:36:57 [INFO] Epoch Time: 9.10s
# 2026-06-29 17:36:57 [INFO]
# Epoch [10/300] | LR: 8.4144372940
# Training: 100%|██████████| 781/781 [00:07<00:00, 101.62it/s]
# 2026-06-29 17:37:05 [INFO] Train Loss: 1.0150 | Train Acc: 79.20% | Reg Loss: 4.2542
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.72it/s]
# 2026-06-29 17:37:06 [INFO] Test Loss: 1.0583 | Test Acc: 77.46%
# 2026-06-29 17:37:06 [INFO] (X) model did not beat reg_loss: 4.254 vs 0.400, accuracy: 77.46%
# 2026-06-29 17:37:06 [INFO] Epoch Time: 8.97s
# 2026-06-29 17:37:06 [INFO]
# Epoch [11/300] | LR: 8.4144372940
# Training: 100%|██████████| 781/781 [00:07<00:00, 101.96it/s]
# 2026-06-29 17:37:14 [INFO] Train Loss: 0.9849 | Train Acc: 80.49% | Reg Loss: 4.5824
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.92it/s]
# 2026-06-29 17:37:15 [INFO] Test Loss: 1.0370 | Test Acc: 78.86%
# 2026-06-29 17:37:15 [INFO] (X) model did not beat reg_loss: 4.582 vs 0.400, accuracy: 78.86%
# 2026-06-29 17:37:15 [INFO] Epoch Time: 9.04s
# 2026-06-29 17:37:15 [INFO]
# Epoch [12/300] | LR: 8.4141883850
# Training: 100%|██████████| 781/781 [00:07<00:00, 102.33it/s]
# 2026-06-29 17:37:23 [INFO] Train Loss: 0.9748 | Train Acc: 80.85% | Reg Loss: 4.8735
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.03it/s]
# 2026-06-29 17:37:24 [INFO] Test Loss: 0.9506 | Test Acc: 81.69%
# 2026-06-29 17:37:24 [INFO] (X) model did not beat reg_loss: 4.874 vs 0.400, accuracy: 81.69%
# 2026-06-29 17:37:24 [INFO] Epoch Time: 8.96s
# 2026-06-29 17:37:24 [INFO]
# Epoch [13/300] | LR: 8.4134435654
# Training: 100%|██████████| 781/781 [00:07<00:00, 102.29it/s]
# 2026-06-29 17:37:32 [INFO] Train Loss: 0.9651 | Train Acc: 81.55% | Reg Loss: 5.1012
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 142.00it/s]
# 2026-06-29 17:37:33 [INFO] Test Loss: 1.0111 | Test Acc: 79.81%
# 2026-06-29 17:37:33 [INFO] (X) model did not beat reg_loss: 5.101 vs 0.400, accuracy: 79.81%
# 2026-06-29 17:37:33 [INFO] Epoch Time: 9.01s
# 2026-06-29 17:37:33 [INFO]
# Epoch [14/300] | LR: 8.4121999741
# Training: 100%|██████████| 781/781 [00:07<00:00, 107.30it/s]
# 2026-06-29 17:37:40 [INFO] Train Loss: 0.9410 | Train Acc: 82.45% | Reg Loss: 5.2380
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.23it/s]
# 2026-06-29 17:37:41 [INFO] Test Loss: 1.0200 | Test Acc: 80.03%
# 2026-06-29 17:37:41 [INFO] (X) model did not beat reg_loss: 5.238 vs 0.400, accuracy: 80.03%
# 2026-06-29 17:37:41 [INFO] Epoch Time: 8.65s
# 2026-06-29 17:37:41 [INFO]
# Epoch [15/300] | LR: 8.4104604721
# Training: 100%|██████████| 781/781 [00:06<00:00, 126.75it/s]
# 2026-06-29 17:37:48 [INFO] Train Loss: 0.9313 | Train Acc: 82.95% | Reg Loss: 5.3362
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 327.54it/s]
# 2026-06-29 17:37:48 [INFO] Test Loss: 0.9793 | Test Acc: 81.32%
# 2026-06-29 17:37:48 [INFO] (X) model did not beat reg_loss: 5.336 vs 0.400, accuracy: 81.32%
# 2026-06-29 17:37:48 [INFO] Epoch Time: 6.68s
# 2026-06-29 17:37:48 [INFO]
# Epoch [16/300] | LR: 8.4082241058
# Training: 100%|██████████| 781/781 [00:03<00:00, 199.64it/s]
# 2026-06-29 17:37:52 [INFO] Train Loss: 0.9297 | Train Acc: 83.03% | Reg Loss: 5.4869
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 325.25it/s]
# 2026-06-29 17:37:53 [INFO] Test Loss: 1.0268 | Test Acc: 79.16%
# 2026-06-29 17:37:53 [INFO] (X) model did not beat reg_loss: 5.487 vs 0.400, accuracy: 79.16%
# 2026-06-29 17:37:53 [INFO] Epoch Time: 4.44s
# 2026-06-29 17:37:53 [INFO]
# Epoch [17/300] | LR: 8.4054908752
# Training: 100%|██████████| 781/781 [00:04<00:00, 187.82it/s]
# 2026-06-29 17:37:57 [INFO] Train Loss: 0.9229 | Train Acc: 83.19% | Reg Loss: 5.5642
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 298.97it/s]
# 2026-06-29 17:37:57 [INFO] Test Loss: 1.0508 | Test Acc: 78.79%
# 2026-06-29 17:37:57 [INFO] (X) model did not beat reg_loss: 5.564 vs 0.400, accuracy: 78.79%
# 2026-06-29 17:37:57 [INFO] Epoch Time: 4.72s
# 2026-06-29 17:37:57 [INFO]
# Epoch [18/300] | LR: 8.4022626877
# Training: 100%|██████████| 781/781 [00:04<00:00, 193.61it/s]
# 2026-06-29 17:38:01 [INFO] Train Loss: 0.9076 | Train Acc: 83.58% | Reg Loss: 5.6401
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 278.73it/s]
# 2026-06-29 17:38:02 [INFO] Test Loss: 0.9914 | Test Acc: 80.36%
# 2026-06-29 17:38:02 [INFO] (X) model did not beat reg_loss: 5.640 vs 0.400, accuracy: 80.36%
# 2026-06-29 17:38:02 [INFO] Epoch Time: 4.64s
# 2026-06-29 17:38:02 [INFO]
# Epoch [19/300] | LR: 8.3985376358
# Training: 100%|██████████| 781/781 [00:04<00:00, 189.96it/s]
# 2026-06-29 17:38:06 [INFO] Train Loss: 0.9074 | Train Acc: 83.76% | Reg Loss: 5.7214
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 321.07it/s]
# 2026-06-29 17:38:07 [INFO] Test Loss: 1.0312 | Test Acc: 77.67%
# 2026-06-29 17:38:07 [INFO] (X) model did not beat reg_loss: 5.721 vs 0.400, accuracy: 77.67%
# 2026-06-29 17:38:07 [INFO] Epoch Time: 4.65s
# 2026-06-29 17:38:07 [INFO]
# Epoch [20/300] | LR: 8.3943176270
# Training: 100%|██████████| 781/781 [00:04<00:00, 172.61it/s]
# 2026-06-29 17:38:11 [INFO] Train Loss: 0.8941 | Train Acc: 84.27% | Reg Loss: 0.4882
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 323.05it/s]
# 2026-06-29 17:38:12 [INFO] Test Loss: 0.9932 | Test Acc: 81.76%
# 2026-06-29 17:38:12 [INFO] (X) model did not beat reg_loss: 0.488 vs 0.400, accuracy: 81.76%
# 2026-06-29 17:38:12 [INFO] Epoch Time: 5.06s
# 2026-06-29 17:38:12 [INFO]
# Epoch [21/300] | LR: 0.7275644541
# Training: 100%|██████████| 781/781 [00:04<00:00, 193.64it/s]
# 2026-06-29 17:38:16 [INFO] Train Loss: 0.8666 | Train Acc: 84.71% | Reg Loss: 0.4765
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 318.04it/s]
# 2026-06-29 17:38:16 [INFO] Test Loss: 0.9113 | Test Acc: 82.74%
# 2026-06-29 17:38:16 [INFO] (X) model did not beat reg_loss: 0.477 vs 0.400, accuracy: 82.74%
# 2026-06-29 17:38:16 [INFO] Epoch Time: 4.56s
# 2026-06-29 17:38:16 [INFO]
# Epoch [22/300] | LR: 0.7271127105
# Training: 100%|██████████| 781/781 [00:04<00:00, 156.95it/s]
# 2026-06-29 17:38:21 [INFO] Train Loss: 0.8574 | Train Acc: 85.21% | Reg Loss: 0.4635
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 146.72it/s]
# 2026-06-29 17:38:22 [INFO] Test Loss: 1.0168 | Test Acc: 79.02%
# 2026-06-29 17:38:22 [INFO] (X) model did not beat reg_loss: 0.463 vs 0.400, accuracy: 79.02%
# 2026-06-29 17:38:22 [INFO] Epoch Time: 6.22s
# 2026-06-29 17:38:22 [INFO]
# Epoch [23/300] | LR: 0.7266181707
# Training: 100%|██████████| 781/781 [00:08<00:00, 89.86it/s]
# 2026-06-29 17:38:31 [INFO] Train Loss: 0.8528 | Train Acc: 85.24% | Reg Loss: 0.4494
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 211.41it/s]
# 2026-06-29 17:38:32 [INFO] Test Loss: 0.9242 | Test Acc: 82.74%
# 2026-06-29 17:38:32 [INFO] (X) model did not beat reg_loss: 0.449 vs 0.400, accuracy: 82.74%
# 2026-06-29 17:38:32 [INFO] Epoch Time: 9.61s
# 2026-06-29 17:38:32 [INFO]
# Epoch [24/300] | LR: 0.7260809541
# Training: 100%|██████████| 781/781 [00:08<00:00, 90.13it/s]
# 2026-06-29 17:38:41 [INFO] Train Loss: 0.8533 | Train Acc: 85.47% | Reg Loss: 0.4443
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 191.69it/s]
# 2026-06-29 17:38:42 [INFO] Test Loss: 0.9064 | Test Acc: 83.20%
# 2026-06-29 17:38:42 [INFO] (X) model did not beat reg_loss: 0.444 vs 0.400, accuracy: 83.20%
# 2026-06-29 17:38:42 [INFO] Epoch Time: 9.67s
# 2026-06-29 17:38:42 [INFO]
# Epoch [25/300] | LR: 0.7255009413
# Training: 100%|██████████| 781/781 [00:08<00:00, 92.64it/s]
# 2026-06-29 17:38:50 [INFO] Train Loss: 0.8515 | Train Acc: 85.49% | Reg Loss: 0.4349
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 142.27it/s]
# 2026-06-29 17:38:51 [INFO] Test Loss: 0.9087 | Test Acc: 83.14%
# 2026-06-29 17:38:51 [INFO] (X) model did not beat reg_loss: 0.435 vs 0.400, accuracy: 83.14%
# 2026-06-29 17:38:51 [INFO] Epoch Time: 9.66s
# 2026-06-29 17:38:51 [INFO]
# Epoch [26/300] | LR: 0.7248783708
# Training: 100%|██████████| 781/781 [00:08<00:00, 93.35it/s]
# 2026-06-29 17:39:00 [INFO] Train Loss: 0.8510 | Train Acc: 85.48% | Reg Loss: 0.4275
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 162.25it/s]
# 2026-06-29 17:39:01 [INFO] Test Loss: 0.9499 | Test Acc: 81.72%
# 2026-06-29 17:39:01 [INFO] (X) model did not beat reg_loss: 0.427 vs 0.400, accuracy: 81.72%
# 2026-06-29 17:39:01 [INFO] Epoch Time: 9.55s
# 2026-06-29 17:39:01 [INFO]
# Epoch [27/300] | LR: 0.7242132425
# Training: 100%|██████████| 781/781 [00:08<00:00, 91.49it/s]
# 2026-06-29 17:39:09 [INFO] Train Loss: 0.8458 | Train Acc: 85.80% | Reg Loss: 0.4185
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 143.12it/s]
# 2026-06-29 17:39:11 [INFO] Test Loss: 0.9133 | Test Acc: 82.81%
# 2026-06-29 17:39:11 [INFO] (X) model did not beat reg_loss: 0.418 vs 0.400, accuracy: 82.81%
# 2026-06-29 17:39:11 [INFO] Epoch Time: 9.72s
# 2026-06-29 17:39:11 [INFO]
# Epoch [28/300] | LR: 0.7235056758
# Training: 100%|██████████| 781/781 [00:08<00:00, 89.94it/s]
# 2026-06-29 17:39:19 [INFO] Train Loss: 0.8497 | Train Acc: 85.46% | Reg Loss: 0.4112
# Evaluating: 100%|██████████| 157/157 [00:00<00:00, 251.62it/s]
# 2026-06-29 17:39:20 [INFO] Test Loss: 0.9184 | Test Acc: 82.60%
# 2026-06-29 17:39:20 [INFO] (X) model did not beat reg_loss: 0.411 vs 0.400, accuracy: 82.60%
# 2026-06-29 17:39:20 [INFO] Epoch Time: 9.33s
# 2026-06-29 17:39:20 [INFO]
# Epoch [29/300] | LR: 0.7227556705
# Training: 100%|██████████| 781/781 [00:09<00:00, 79.77it/s]
# 2026-06-29 17:39:30 [INFO] Train Loss: 0.8483 | Train Acc: 85.66% | Reg Loss: 0.4020
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.52it/s]
# 2026-06-29 17:39:31 [INFO] Test Loss: 0.9146 | Test Acc: 82.85%
# 2026-06-29 17:39:31 [INFO] (X) model did not beat reg_loss: 0.402 vs 0.400, accuracy: 82.85%
# 2026-06-29 17:39:31 [INFO] Epoch Time: 11.17s
# 2026-06-29 17:39:31 [INFO]
# Epoch [30/300] | LR: 0.7219634652
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.86it/s]
# 2026-06-29 17:39:41 [INFO] Train Loss: 0.8464 | Train Acc: 85.76% | Reg Loss: 0.3914
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.77it/s]
# 2026-06-29 17:39:42 [INFO] Test Loss: 0.8857 | Test Acc: 84.15%
# 2026-06-29 17:39:42 [INFO] ✓ Saved best model with best reg_loss: 0.391, accuracy: 84.15%
# 2026-06-29 17:39:42 [INFO] Epoch Time: 10.85s
# 2026-06-29 17:39:42 [INFO]
# Epoch [31/300] | LR: 0.7211290002
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.73it/s]
# 2026-06-29 17:39:51 [INFO] Train Loss: 0.8468 | Train Acc: 85.54% | Reg Loss: 0.3895
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.83it/s]
# 2026-06-29 17:39:53 [INFO] Test Loss: 0.8630 | Test Acc: 84.55%
# 2026-06-29 17:39:53 [INFO] ✓ Saved best model with best reg_loss: 0.389, accuracy: 84.55%
# 2026-06-29 17:39:53 [INFO] Epoch Time: 10.76s
# 2026-06-29 17:39:53 [INFO]
# Epoch [32/300] | LR: 0.7202524543
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.70it/s]
# 2026-06-29 17:40:02 [INFO] Train Loss: 0.8513 | Train Acc: 85.54% | Reg Loss: 0.3873
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.51it/s]
# 2026-06-29 17:40:03 [INFO] Test Loss: 0.9292 | Test Acc: 82.61%
# 2026-06-29 17:40:03 [INFO] ✓ Saved best model with best reg_loss: 0.387, accuracy: 82.61%
# 2026-06-29 17:40:03 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:40:03 [INFO]
# Epoch [33/300] | LR: 0.7193338871
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.89it/s]
# 2026-06-29 17:40:13 [INFO] Train Loss: 0.8435 | Train Acc: 85.78% | Reg Loss: 0.3844
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.58it/s]
# 2026-06-29 17:40:14 [INFO] Test Loss: 0.8822 | Test Acc: 84.74%
# 2026-06-29 17:40:14 [INFO] ✓ Saved best model with best reg_loss: 0.384, accuracy: 84.74%
# 2026-06-29 17:40:14 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:40:14 [INFO]
# Epoch [34/300] | LR: 0.7183734179
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.64it/s]
# 2026-06-29 17:40:24 [INFO] Train Loss: 0.8453 | Train Acc: 85.72% | Reg Loss: 0.3844
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.21it/s]
# 2026-06-29 17:40:25 [INFO] Test Loss: 0.9486 | Test Acc: 81.50%
# 2026-06-29 17:40:25 [INFO] ✓ Saved best model with best reg_loss: 0.384, accuracy: 81.50%
# 2026-06-29 17:40:25 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:40:25 [INFO]
# Epoch [35/300] | LR: 0.7173712254
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.70it/s]
# 2026-06-29 17:40:35 [INFO] Train Loss: 0.8447 | Train Acc: 85.80% | Reg Loss: 0.3844
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 142.54it/s]
# 2026-06-29 17:40:36 [INFO] Test Loss: 0.9274 | Test Acc: 82.21%
# 2026-06-29 17:40:36 [INFO] (X) model did not beat reg_loss: 0.384 vs 0.384, accuracy: 82.21%
# 2026-06-29 17:40:36 [INFO] Epoch Time: 10.74s
# 2026-06-29 17:40:36 [INFO]
# Epoch [36/300] | LR: 0.7163273692
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.82it/s]
# 2026-06-29 17:40:45 [INFO] Train Loss: 0.8424 | Train Acc: 85.99% | Reg Loss: 0.3827
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.32it/s]
# 2026-06-29 17:40:47 [INFO] Test Loss: 0.9026 | Test Acc: 83.37%
# 2026-06-29 17:40:47 [INFO] ✓ Saved best model with best reg_loss: 0.383, accuracy: 83.37%
# 2026-06-29 17:40:47 [INFO] Epoch Time: 10.81s
# 2026-06-29 17:40:47 [INFO]
# Epoch [37/300] | LR: 0.7152419686
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.55it/s]
# 2026-06-29 17:40:56 [INFO] Train Loss: 0.8421 | Train Acc: 85.90% | Reg Loss: 0.3830
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.01it/s]
# 2026-06-29 17:40:57 [INFO] Test Loss: 0.9080 | Test Acc: 82.75%
# 2026-06-29 17:40:57 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.383, accuracy: 82.75%
# 2026-06-29 17:40:57 [INFO] Epoch Time: 10.75s
# 2026-06-29 17:40:57 [INFO]
# Epoch [38/300] | LR: 0.7141151428
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.79it/s]
# 2026-06-29 17:41:07 [INFO] Train Loss: 0.8390 | Train Acc: 85.93% | Reg Loss: 0.3822
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.36it/s]
# 2026-06-29 17:41:08 [INFO] Test Loss: 0.8989 | Test Acc: 83.01%
# 2026-06-29 17:41:08 [INFO] ✓ Saved best model with best reg_loss: 0.382, accuracy: 83.01%
# 2026-06-29 17:41:08 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:41:08 [INFO]
# Epoch [39/300] | LR: 0.7129470706
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.34it/s]
# 2026-06-29 17:41:18 [INFO] Train Loss: 0.8363 | Train Acc: 86.10% | Reg Loss: 0.3833
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.15it/s]
# 2026-06-29 17:41:19 [INFO] Test Loss: 0.8658 | Test Acc: 85.13%
# 2026-06-29 17:41:19 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.382, accuracy: 85.13%
# 2026-06-29 17:41:19 [INFO] Epoch Time: 10.75s
# 2026-06-29 17:41:19 [INFO]
# Epoch [40/300] | LR: 0.7117378712
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.96it/s]
# 2026-06-29 17:41:29 [INFO] Train Loss: 0.8371 | Train Acc: 86.14% | Reg Loss: 0.3845
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.22it/s]
# 2026-06-29 17:41:30 [INFO] Test Loss: 0.8883 | Test Acc: 83.79%
# 2026-06-29 17:41:30 [INFO] (X) model did not beat reg_loss: 0.385 vs 0.382, accuracy: 83.79%
# 2026-06-29 17:41:30 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:41:30 [INFO]
# Epoch [41/300] | LR: 0.7104876637
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.87it/s]
# 2026-06-29 17:41:39 [INFO] Train Loss: 0.8358 | Train Acc: 86.15% | Reg Loss: 0.3830
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.78it/s]
# 2026-06-29 17:41:40 [INFO] Test Loss: 0.9477 | Test Acc: 82.07%
# 2026-06-29 17:41:40 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.382, accuracy: 82.07%
# 2026-06-29 17:41:40 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:41:40 [INFO]
# Epoch [42/300] | LR: 0.7091966271
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.90it/s]
# 2026-06-29 17:41:50 [INFO] Train Loss: 0.8323 | Train Acc: 86.21% | Reg Loss: 0.3831
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.03it/s]
# 2026-06-29 17:41:51 [INFO] Test Loss: 0.9132 | Test Acc: 83.50%
# 2026-06-29 17:41:51 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.382, accuracy: 83.50%
# 2026-06-29 17:41:51 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:41:51 [INFO]
# Epoch [43/300] | LR: 0.7078648806
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.78it/s]
# 2026-06-29 17:42:01 [INFO] Train Loss: 0.8292 | Train Acc: 86.32% | Reg Loss: 0.3844
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.69it/s]
# 2026-06-29 17:42:02 [INFO] Test Loss: 0.8906 | Test Acc: 83.90%
# 2026-06-29 17:42:02 [INFO] (X) model did not beat reg_loss: 0.384 vs 0.382, accuracy: 83.90%
# 2026-06-29 17:42:02 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:42:02 [INFO]
# Epoch [44/300] | LR: 0.7064926028
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.77it/s]
# 2026-06-29 17:42:12 [INFO] Train Loss: 0.8308 | Train Acc: 86.37% | Reg Loss: 0.3829
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.92it/s]
# 2026-06-29 17:42:13 [INFO] Test Loss: 0.9060 | Test Acc: 83.66%
# 2026-06-29 17:42:13 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.382, accuracy: 83.66%
# 2026-06-29 17:42:13 [INFO] Epoch Time: 10.77s
# 2026-06-29 17:42:13 [INFO]
# Epoch [45/300] | LR: 0.7050799727
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.66it/s]
# 2026-06-29 17:42:22 [INFO] Train Loss: 0.8296 | Train Acc: 86.36% | Reg Loss: 0.3829
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.39it/s]
# 2026-06-29 17:42:24 [INFO] Test Loss: 0.8822 | Test Acc: 84.76%
# 2026-06-29 17:42:24 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.382, accuracy: 84.76%
# 2026-06-29 17:42:24 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:42:24 [INFO]
# Epoch [46/300] | LR: 0.7036271095
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.96it/s]
# 2026-06-29 17:42:33 [INFO] Train Loss: 0.8290 | Train Acc: 86.34% | Reg Loss: 0.3845
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.78it/s]
# 2026-06-29 17:42:34 [INFO] Test Loss: 0.8922 | Test Acc: 84.12%
# 2026-06-29 17:42:34 [INFO] (X) model did not beat reg_loss: 0.384 vs 0.382, accuracy: 84.12%
# 2026-06-29 17:42:34 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:42:34 [INFO]
# Epoch [47/300] | LR: 0.7021342516
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.69it/s]
# 2026-06-29 17:42:44 [INFO] Train Loss: 0.8248 | Train Acc: 86.60% | Reg Loss: 0.3852
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.65it/s]
# 2026-06-29 17:42:45 [INFO] Test Loss: 0.9181 | Test Acc: 83.05%
# 2026-06-29 17:42:45 [INFO] (X) model did not beat reg_loss: 0.385 vs 0.382, accuracy: 83.05%
# 2026-06-29 17:42:45 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:42:45 [INFO]
# Epoch [48/300] | LR: 0.7006015778
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.80it/s]
# 2026-06-29 17:42:55 [INFO] Train Loss: 0.8246 | Train Acc: 86.49% | Reg Loss: 0.3829
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.42it/s]
# 2026-06-29 17:42:56 [INFO] Test Loss: 0.8864 | Test Acc: 84.12%
# 2026-06-29 17:42:56 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.382, accuracy: 84.12%
# 2026-06-29 17:42:56 [INFO] Epoch Time: 10.77s
# 2026-06-29 17:42:56 [INFO]
# Epoch [49/300] | LR: 0.6990291476
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.01it/s]
# 2026-06-29 17:43:06 [INFO] Train Loss: 0.8276 | Train Acc: 86.50% | Reg Loss: 0.3859
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 145.20it/s]
# 2026-06-29 17:43:07 [INFO] Test Loss: 0.9496 | Test Acc: 81.36%
# 2026-06-29 17:43:07 [INFO] (X) model did not beat reg_loss: 0.386 vs 0.382, accuracy: 81.36%
# 2026-06-29 17:43:07 [INFO] Epoch Time: 10.74s
# 2026-06-29 17:43:07 [INFO]
# Epoch [50/300] | LR: 0.6974172592
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.55it/s]
# 2026-06-29 17:43:16 [INFO] Train Loss: 0.8240 | Train Acc: 86.55% | Reg Loss: 0.3837
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.58it/s]
# 2026-06-29 17:43:18 [INFO] Test Loss: 0.8661 | Test Acc: 84.79%
# 2026-06-29 17:43:18 [INFO] (X) model did not beat reg_loss: 0.384 vs 0.382, accuracy: 84.79%
# 2026-06-29 17:43:18 [INFO] Epoch Time: 10.83s
# 2026-06-29 17:43:18 [INFO]
# Epoch [51/300] | LR: 0.6957660913
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.71it/s]
# 2026-06-29 17:43:27 [INFO] Train Loss: 0.8220 | Train Acc: 86.69% | Reg Loss: 0.3825
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.57it/s]
# 2026-06-29 17:43:28 [INFO] Test Loss: 0.8779 | Test Acc: 84.34%
# 2026-06-29 17:43:28 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.382, accuracy: 84.34%
# 2026-06-29 17:43:28 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:43:28 [INFO]
# Epoch [52/300] | LR: 0.6940758228
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.16it/s]
# 2026-06-29 17:43:38 [INFO] Train Loss: 0.8207 | Train Acc: 86.87% | Reg Loss: 0.3818
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.51it/s]
# 2026-06-29 17:43:39 [INFO] Test Loss: 0.8899 | Test Acc: 83.77%
# 2026-06-29 17:43:39 [INFO] ✓ Saved best model with best reg_loss: 0.382, accuracy: 83.77%
# 2026-06-29 17:43:39 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:43:39 [INFO]
# Epoch [53/300] | LR: 0.6923465729
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.80it/s]
# 2026-06-29 17:43:49 [INFO] Train Loss: 0.8192 | Train Acc: 87.00% | Reg Loss: 0.3848
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.83it/s]
# 2026-06-29 17:43:50 [INFO] Test Loss: 0.9122 | Test Acc: 83.47%
# 2026-06-29 17:43:50 [INFO] (X) model did not beat reg_loss: 0.385 vs 0.382, accuracy: 83.47%
# 2026-06-29 17:43:50 [INFO] Epoch Time: 10.75s
# 2026-06-29 17:43:50 [INFO]
# Epoch [54/300] | LR: 0.6905786991
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.85it/s]
# 2026-06-29 17:43:59 [INFO] Train Loss: 0.8194 | Train Acc: 86.87% | Reg Loss: 0.3825
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.34it/s]
# 2026-06-29 17:44:01 [INFO] Test Loss: 0.8893 | Test Acc: 83.76%
# 2026-06-29 17:44:01 [INFO] (X) model did not beat reg_loss: 0.382 vs 0.382, accuracy: 83.76%
# 2026-06-29 17:44:01 [INFO] Epoch Time: 10.81s
# 2026-06-29 17:44:01 [INFO]
# Epoch [55/300] | LR: 0.6887723207
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.87it/s]
# 2026-06-29 17:44:10 [INFO] Train Loss: 0.8150 | Train Acc: 87.07% | Reg Loss: 0.3812
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.44it/s]
# 2026-06-29 17:44:11 [INFO] Test Loss: 0.9036 | Test Acc: 83.40%
# 2026-06-29 17:44:11 [INFO] ✓ Saved best model with best reg_loss: 0.381, accuracy: 83.40%
# 2026-06-29 17:44:11 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:44:11 [INFO]
# Epoch [56/300] | LR: 0.6869276762
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.91it/s]
# 2026-06-29 17:44:21 [INFO] Train Loss: 0.8179 | Train Acc: 86.98% | Reg Loss: 0.3816
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 142.31it/s]
# 2026-06-29 17:44:22 [INFO] Test Loss: 0.9067 | Test Acc: 83.18%
# 2026-06-29 17:44:22 [INFO] (X) model did not beat reg_loss: 0.382 vs 0.381, accuracy: 83.18%
# 2026-06-29 17:44:22 [INFO] Epoch Time: 10.76s
# 2026-06-29 17:44:22 [INFO]
# Epoch [57/300] | LR: 0.6850449443
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.75it/s]
# 2026-06-29 17:44:32 [INFO] Train Loss: 0.8210 | Train Acc: 86.80% | Reg Loss: 0.3832
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 143.65it/s]
# 2026-06-29 17:44:33 [INFO] Test Loss: 0.8912 | Test Acc: 83.91%
# 2026-06-29 17:44:33 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.381, accuracy: 83.91%
# 2026-06-29 17:44:33 [INFO] Epoch Time: 10.77s
# 2026-06-29 17:44:33 [INFO]
# Epoch [58/300] | LR: 0.6831243634
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.86it/s]
# 2026-06-29 17:44:43 [INFO] Train Loss: 0.8170 | Train Acc: 86.90% | Reg Loss: 0.3843
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.80it/s]
# 2026-06-29 17:44:44 [INFO] Test Loss: 0.8650 | Test Acc: 84.95%
# 2026-06-29 17:44:44 [INFO] (X) model did not beat reg_loss: 0.384 vs 0.381, accuracy: 84.95%
# 2026-06-29 17:44:44 [INFO] Epoch Time: 10.81s
# 2026-06-29 17:44:44 [INFO]
# Epoch [59/300] | LR: 0.6811662316
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.08it/s]
# 2026-06-29 17:44:53 [INFO] Train Loss: 0.8179 | Train Acc: 86.83% | Reg Loss: 0.3832
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.16it/s]
# 2026-06-29 17:44:55 [INFO] Test Loss: 0.9231 | Test Acc: 82.53%
# 2026-06-29 17:44:55 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.381, accuracy: 82.53%
# 2026-06-29 17:44:55 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:44:55 [INFO]
# Epoch [60/300] | LR: 0.6791707277
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.83it/s]
# 2026-06-29 17:45:04 [INFO] Train Loss: 0.8122 | Train Acc: 87.33% | Reg Loss: 0.3793
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.95it/s]
# 2026-06-29 17:45:05 [INFO] Test Loss: 0.8928 | Test Acc: 83.87%
# 2026-06-29 17:45:05 [INFO] ✓ Saved best model with best reg_loss: 0.379, accuracy: 83.87%
# 2026-06-29 17:45:05 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:45:05 [INFO]
# Epoch [61/300] | LR: 0.6771380305
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.08it/s]
# 2026-06-29 17:45:15 [INFO] Train Loss: 0.8112 | Train Acc: 87.29% | Reg Loss: 0.3791
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 143.95it/s]
# 2026-06-29 17:45:16 [INFO] Test Loss: 0.8766 | Test Acc: 84.91%
# 2026-06-29 17:45:16 [INFO] ✓ Saved best model with best reg_loss: 0.379, accuracy: 84.91%
# 2026-06-29 17:45:16 [INFO] Epoch Time: 10.76s
# 2026-06-29 17:45:16 [INFO]
# Epoch [62/300] | LR: 0.6750684381
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.76it/s]
# 2026-06-29 17:45:26 [INFO] Train Loss: 0.8158 | Train Acc: 86.96% | Reg Loss: 0.3834
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.81it/s]
# 2026-06-29 17:45:27 [INFO] Test Loss: 0.9093 | Test Acc: 83.45%
# 2026-06-29 17:45:27 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.379, accuracy: 83.45%
# 2026-06-29 17:45:27 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:45:27 [INFO]
# Epoch [63/300] | LR: 0.6729622483
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.68it/s]
# 2026-06-29 17:45:37 [INFO] Train Loss: 0.8113 | Train Acc: 87.19% | Reg Loss: 0.3848
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.70it/s]
# 2026-06-29 17:45:38 [INFO] Test Loss: 0.8831 | Test Acc: 84.60%
# 2026-06-29 17:45:38 [INFO] (X) model did not beat reg_loss: 0.385 vs 0.379, accuracy: 84.60%
# 2026-06-29 17:45:38 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:45:38 [INFO]
# Epoch [64/300] | LR: 0.6708195806
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.85it/s]
# 2026-06-29 17:45:47 [INFO] Train Loss: 0.8113 | Train Acc: 87.18% | Reg Loss: 0.3830
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.48it/s]
# 2026-06-29 17:45:49 [INFO] Test Loss: 0.8835 | Test Acc: 83.57%
# 2026-06-29 17:45:49 [INFO] (X) model did not beat reg_loss: 0.383 vs 0.379, accuracy: 83.57%
# 2026-06-29 17:45:49 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:45:49 [INFO]
# Epoch [65/300] | LR: 0.6686407924
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.65it/s]
# 2026-06-29 17:45:58 [INFO] Train Loss: 0.8106 | Train Acc: 87.17% | Reg Loss: 0.3818
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 146.91it/s]
# 2026-06-29 17:45:59 [INFO] Test Loss: 0.8633 | Test Acc: 85.15%
# 2026-06-29 17:45:59 [INFO] (X) model did not beat reg_loss: 0.382 vs 0.379, accuracy: 85.15%
# 2026-06-29 17:45:59 [INFO] Epoch Time: 10.72s
# 2026-06-29 17:45:59 [INFO]
# Epoch [66/300] | LR: 0.6664260626
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.84it/s]
# 2026-06-29 17:46:09 [INFO] Train Loss: 0.8065 | Train Acc: 87.27% | Reg Loss: 0.3797
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.92it/s]
# 2026-06-29 17:46:10 [INFO] Test Loss: 0.8907 | Test Acc: 84.28%
# 2026-06-29 17:46:10 [INFO] (X) model did not beat reg_loss: 0.380 vs 0.379, accuracy: 84.28%
# 2026-06-29 17:46:10 [INFO] Epoch Time: 10.82s
# 2026-06-29 17:46:10 [INFO]
# Epoch [67/300] | LR: 0.6641757488
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.74it/s]
# 2026-06-29 17:46:20 [INFO] Train Loss: 0.8132 | Train Acc: 87.09% | Reg Loss: 0.3805
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.00it/s]
# 2026-06-29 17:46:21 [INFO] Test Loss: 0.9435 | Test Acc: 82.28%
# 2026-06-29 17:46:21 [INFO] (X) model did not beat reg_loss: 0.381 vs 0.379, accuracy: 82.28%
# 2026-06-29 17:46:21 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:46:21 [INFO]
# Epoch [68/300] | LR: 0.6618900895
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.89it/s]
# 2026-06-29 17:46:30 [INFO] Train Loss: 0.8085 | Train Acc: 87.28% | Reg Loss: 0.3803
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.21it/s]
# 2026-06-29 17:46:32 [INFO] Test Loss: 0.9088 | Test Acc: 83.51%
# 2026-06-29 17:46:32 [INFO] (X) model did not beat reg_loss: 0.380 vs 0.379, accuracy: 83.51%
# 2026-06-29 17:46:32 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:46:32 [INFO]
# Epoch [69/300] | LR: 0.6595692635
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.99it/s]
# 2026-06-29 17:46:41 [INFO] Train Loss: 0.8061 | Train Acc: 87.44% | Reg Loss: 0.3783
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 146.55it/s]
# 2026-06-29 17:46:42 [INFO] Test Loss: 0.8554 | Test Acc: 85.42%
# 2026-06-29 17:46:42 [INFO] ✓ Saved best model with best reg_loss: 0.378, accuracy: 85.42%
# 2026-06-29 17:46:42 [INFO] Epoch Time: 10.75s
# 2026-06-29 17:46:42 [INFO]
# Epoch [70/300] | LR: 0.6572136283
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.82it/s]
# 2026-06-29 17:46:52 [INFO] Train Loss: 0.8084 | Train Acc: 87.26% | Reg Loss: 0.3837
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.97it/s]
# 2026-06-29 17:46:53 [INFO] Test Loss: 0.8840 | Test Acc: 83.95%
# 2026-06-29 17:46:53 [INFO] (X) model did not beat reg_loss: 0.384 vs 0.378, accuracy: 83.95%
# 2026-06-29 17:46:53 [INFO] Epoch Time: 10.81s
# 2026-06-29 17:46:53 [INFO]
# Epoch [71/300] | LR: 0.6548234820
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.72it/s]
# 2026-06-29 17:47:03 [INFO] Train Loss: 0.8025 | Train Acc: 87.52% | Reg Loss: 0.3777
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.17it/s]
# 2026-06-29 17:47:04 [INFO] Test Loss: 0.8239 | Test Acc: 86.52%
# 2026-06-29 17:47:04 [INFO] ✓ Saved best model with best reg_loss: 0.378, accuracy: 86.52%
# 2026-06-29 17:47:04 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:47:04 [INFO]
# Epoch [72/300] | LR: 0.6523990035
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.88it/s]
# 2026-06-29 17:47:14 [INFO] Train Loss: 0.8060 | Train Acc: 87.40% | Reg Loss: 0.3777
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 146.30it/s]
# 2026-06-29 17:47:15 [INFO] Test Loss: 0.8667 | Test Acc: 85.50%
# 2026-06-29 17:47:15 [INFO] ✓ Saved best model with best reg_loss: 0.378, accuracy: 85.50%
# 2026-06-29 17:47:15 [INFO] Epoch Time: 10.73s
# 2026-06-29 17:47:15 [INFO]
# Epoch [73/300] | LR: 0.6499406099
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.99it/s]
# 2026-06-29 17:47:24 [INFO] Train Loss: 0.7989 | Train Acc: 87.70% | Reg Loss: 0.3754
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.50it/s]
# 2026-06-29 17:47:26 [INFO] Test Loss: 0.8917 | Test Acc: 84.09%
# 2026-06-29 17:47:26 [INFO] ✓ Saved best model with best reg_loss: 0.375, accuracy: 84.09%
# 2026-06-29 17:47:26 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:47:26 [INFO]
# Epoch [74/300] | LR: 0.6474485397
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.90it/s]
# 2026-06-29 17:47:35 [INFO] Train Loss: 0.8053 | Train Acc: 87.49% | Reg Loss: 0.3773
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.44it/s]
# 2026-06-29 17:47:36 [INFO] Test Loss: 0.9243 | Test Acc: 82.46%
# 2026-06-29 17:47:36 [INFO] (X) model did not beat reg_loss: 0.377 vs 0.375, accuracy: 82.46%
# 2026-06-29 17:47:36 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:47:36 [INFO]
# Epoch [75/300] | LR: 0.6449229717
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.90it/s]
# 2026-06-29 17:47:46 [INFO] Train Loss: 0.8012 | Train Acc: 87.66% | Reg Loss: 0.3757
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.55it/s]
# 2026-06-29 17:47:47 [INFO] Test Loss: 0.8976 | Test Acc: 83.84%
# 2026-06-29 17:47:47 [INFO] (X) model did not beat reg_loss: 0.376 vs 0.375, accuracy: 83.84%
# 2026-06-29 17:47:47 [INFO] Epoch Time: 10.78s
# 2026-06-29 17:47:47 [INFO]
# Epoch [76/300] | LR: 0.6423644423
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.71it/s]
# 2026-06-29 17:47:57 [INFO] Train Loss: 0.7998 | Train Acc: 87.73% | Reg Loss: 0.3738
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.14it/s]
# 2026-06-29 17:47:58 [INFO] Test Loss: 0.8708 | Test Acc: 84.88%
# 2026-06-29 17:47:58 [INFO] ✓ Saved best model with best reg_loss: 0.374, accuracy: 84.88%
# 2026-06-29 17:47:58 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:47:58 [INFO]
# Epoch [77/300] | LR: 0.6397730112
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.11it/s]
# 2026-06-29 17:48:07 [INFO] Train Loss: 0.7956 | Train Acc: 87.93% | Reg Loss: 0.3738
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 139.71it/s]
# 2026-06-29 17:48:09 [INFO] Test Loss: 0.8494 | Test Acc: 86.05%
# 2026-06-29 17:48:09 [INFO] ✓ Saved best model with best reg_loss: 0.374, accuracy: 86.05%
# 2026-06-29 17:48:09 [INFO] Epoch Time: 10.79s
# 2026-06-29 17:48:09 [INFO]
# Epoch [78/300] | LR: 0.6371491551
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.82it/s]
# 2026-06-29 17:48:18 [INFO] Train Loss: 0.7999 | Train Acc: 87.66% | Reg Loss: 0.3747
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 142.25it/s]
# 2026-06-29 17:48:19 [INFO] Test Loss: 0.9072 | Test Acc: 83.26%
# 2026-06-29 17:48:19 [INFO] (X) model did not beat reg_loss: 0.375 vs 0.374, accuracy: 83.26%
# 2026-06-29 17:48:19 [INFO] Epoch Time: 10.75s
# 2026-06-29 17:48:19 [INFO]
# Epoch [79/300] | LR: 0.6344931126
# Training: 100%|██████████| 781/781 [00:09<00:00, 82.70it/s]
# 2026-06-29 17:48:29 [INFO] Train Loss: 0.7985 | Train Acc: 87.69% | Reg Loss: 0.3747
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 140.30it/s]
# 2026-06-29 17:48:30 [INFO] Test Loss: 0.8650 | Test Acc: 85.09%
# 2026-06-29 17:48:30 [INFO] (X) model did not beat reg_loss: 0.375 vs 0.374, accuracy: 85.09%
# 2026-06-29 17:48:30 [INFO] Epoch Time: 10.80s
# 2026-06-29 17:48:30 [INFO]
# Epoch [80/300] | LR: 0.6318051815
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.13it/s]
# 2026-06-29 17:48:40 [INFO] Train Loss: 0.8007 | Train Acc: 87.59% | Reg Loss: 0.3759
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 145.10it/s]
# 2026-06-29 17:48:41 [INFO] Test Loss: 0.9019 | Test Acc: 84.19%
# 2026-06-29 17:48:41 [INFO] (X) model did not beat reg_loss: 0.376 vs 0.374, accuracy: 84.19%
# 2026-06-29 17:48:41 [INFO] Epoch Time: 10.74s
# 2026-06-29 17:48:41 [INFO]
# Epoch [81/300] | LR: 0.6290857792
# Training: 100%|██████████| 781/781 [00:09<00:00, 83.16it/s]
# 2026-06-29 17:48:51 [INFO] Train Loss: 0.7966 | Train Acc: 87.74% | Reg Loss: 0.3753
# Evaluating: 100%|██████████| 157/157 [00:01<00:00, 141.22it/s]
# 2026-06-29 17:48:52 [INFO] Test Loss: 0.8538 | Test Acc: 85.90%
# 2026-06-29 17:48:52 [INFO] (X) model did not beat reg_loss: 0.375 vs 0.374, accuracy: 85.90%
# 2026-06-29 17:48:52 [INFO] Epoch Time: 10.77s
# 2026-06-29 17:48:52 [INFO]
# Epoch [82/300] | LR: 0.6263350844
# Training:  35%|███▌      | 277/781 [00:03<00:06, 82.40it/s]

# %%
share_done = hist["per_layer_share_done"]
shares_done = np.array(share_done)
print(shares_done.shape)
plt.plot(shares_done)
for i in range(shares_done.shape[1]):
    print(shares_done[-1,i])

# %%
epochs = [{"num_epochs":100, "REG_wait_epochs":15}, {"num_epochs":200, "REG_wait_epochs":35}, {"num_epochs":500, "REG_wait_epochs":45}, {"num_epochs":2000, "REG_wait_epochs":80}]
for config in epochs:
    start_i = 0 if config["num_epochs"] != 100 else 4
    for i in range(start_i,5):
        hist, model,optimizer = longrun_scale_layer(5e-4,config,f"COMP_NoDoubleCos_{config["num_epochs"]}_{i}")

hist, model,optimizer = longrun_scale_layer(5e-4,{"num_epochs":8000, "REG_wait_epochs":100},f"COMP_NoDoubleCos_{8000}_{0}")

# %%
for param in optimizer.param_groups[-1]["params"]:
    print(param.shape)

# %%
hist, model,optimizer = longrun_scale_layer(5e-4,{},"long2k-reg")

# %%
res = []
for i in range(5):
    res_once = {}
    for beta in [1e-2,5e-3,1e-3,5e-4,1e-4]:
        hist, model, optimizer = longrun_scale_layer(beta,"test_betDec_fix_momReb_test_lritem_no_betaschedule")
        res_once[beta]= hist
    res.append(res_once)

# %%
betas = res[0].keys()
for beta in betas:
    accs = [res[i][beta]["test_acc"][-1] for i in range(len(res))]
    print(beta,accs,torch.tensor(accs).mean().item(),torch.tensor(accs).var().item())

# %% [markdown]
# print(beta,accs,torch.tensor(accs).mean().item(),torch.tensor(accs).var().item())
#
# 0.01 [90.33, 90.55, 90.15, 90.52, 90.53] 90.41600036621094 0.029979677870869637
#
# 0.005 [91.03, 90.67, 90.71, 90.72, 90.32] 90.69000244140625 0.06354987621307373
#
# 0.001 [91.74, 91.44, 91.7, 91.69, 91.86] 91.68599700927734 0.023479677736759186
#
# 0.0005 [92.15, 91.92, 91.42, 91.87, 91.59] 91.78999328613281 0.0824509710073471
#
# 0.0001 [91.57, 91.29, 91.52, 91.51, 91.58] 91.49400329589844 0.013929947279393673

# %%
hist, model,optimizer = longrun_scale_layer(8e-4,"fixed-netadecay")

# %%
train_loader, val_loader = create_data_loaders(
            "~/data",
            64,
            0,
            False,
            32,
            debug=False
        )
# param_dict = {group["params"][0]:group for group in optimizer.param_groups if len(group["params"])==1 }
criterion = nn.CrossEntropyLoss(label_smoothing=0.1).to(DEVICE)  #
print(evaluate(model._orig_mod,val_loader,criterion,DEVICE))
# rebalance_layers(model,param_dict,factor_function=factor_function_test)
print(evaluate(model,val_loader,criterion,DEVICE))

# %%
dir(model.conv1)

# %%
names = {param:name for name,param in model.named_parameters()}

# %%
for param_group in optimizer.param_groups:
    name = [names[param_group["params"][i]] for i in range(len(param_group["params"]))]
    print(name,param_group.get("weight_decay",0),param_group.get("lr",0),param_group.get("weight_decay",0) * param_group.get("lr",0) )
    print()

# %%
model.linear[1].scale.mean()

# %%
plt.hist(model.conv1[0].weight.detach().cpu().flatten(),bins = 40)

# %%
model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2.load_state_dict(model.state_dict())

# %%
from tqdm import tqdm
def evaluate(model, loader, criterion, device,transform_train_x_dtype = torch.float32, amp=False):
    model.eval()
    running_loss = torch.zeros((), device=device, requires_grad=False)
    correct = torch.zeros((), device=device, requires_grad=False)
    total = 0

    pbar = tqdm(loader, desc="Evaluating")
    for images, labels in pbar:
        #torch.compiler.cudagraph_mark_step_begin() # probably not needed
        images: torch.Tensor
        labels: torch.Tensor
        images, labels = images.to(device,transform_train_x_dtype, non_blocking=True), labels.to(
            device, non_blocking=True
        )
        #with torch.amp.autocast("cuda",enabled=amp):
        outputs = model(images)
        loss = criterion(outputs, labels)

        running_loss += loss.detach()
        _, predicted = outputs.max(1)
        correct += predicted.eq(labels).sum().detach()
        total += labels.size(0)

    avg_loss = running_loss.item() / len(loader)
    test_accuracy = 100.0 * correct.item() / total
    return avg_loss, test_accuracy

# %%
train_loader, val_loader = create_data_loaders(
            "~/data",
            128,
            11,
            False,
            32,
            debug=False
        )

# %%
print("Testing: fp32_orig_mod ,fp32, fp32amp, bfp16")
criterion = nn.CrossEntropyLoss(label_smoothing=0.1).to(DEVICE)  #
model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2:ResNet
model2.load_state_dict(model.state_dict())
print(evaluate(model2._orig_mod,val_loader,criterion,DEVICE))
# rebalance_layers(model,param_dict,factor_function=factor_function_test)
print(evaluate(model2,val_loader,criterion,DEVICE))
print(evaluate(model2,val_loader,criterion,DEVICE,amp=True))
model2 = model2.to(torch.bfloat16)
print(evaluate(model2,val_loader,criterion,DEVICE,transform_train_x_dtype=torch.bfloat16))

# %%
print("Testing: fp32, fp32amp, fp16")
criterion = nn.CrossEntropyLoss(label_smoothing=0.1).to(DEVICE)  #
model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2:ResNet
model2.load_state_dict(model.state_dict())
print(evaluate(model2,val_loader,criterion,DEVICE))
print(evaluate(model2,val_loader,criterion,DEVICE,amp=True))
model2 = model2.to(torch.float16)
print(evaluate(model2._orig_mod,val_loader,criterion,DEVICE,transform_train_x_dtype=torch.float16))

# %%
print("Testing: fp8_per_tensor_scale, fp8_per_row_scale")
from torchao.quantization import (
    Float8DynamicActivationFloat8WeightConfig,
    PerRow,
    PerTensor,
    quantize_,
)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1).to(DEVICE)  #
model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2:ResNet
model2.load_state_dict(model.state_dict())
quantize_(model2, Float8DynamicActivationFloat8WeightConfig(granularity=PerTensor()))

print(evaluate(model2,val_loader,criterion,DEVICE,transform_train_x_dtype=torch.float16))

model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2:ResNet
model2.load_state_dict(model.state_dict())
quantize_(model2, Float8DynamicActivationFloat8WeightConfig(granularity=PerRow()))
print(evaluate(model2,val_loader,criterion,DEVICE,transform_train_x_dtype=torch.float16))

# %%
print("Testing: int8_weight_only, int4_weight_only, int2_weight_only")
from torchao.quantization import (
    Float8DynamicActivationFloat8WeightConfig,
    PerRow,
    PerTensor,
    quantize_,Int8WeightOnlyConfig,Int4WeightOnlyConfig,IntxWeightOnlyConfig
)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1).to(DEVICE)  #

model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2:ResNet
model2.load_state_dict(model.state_dict())
quantize_(model2, Int8WeightOnlyConfig())
print(evaluate(model2,val_loader,criterion,DEVICE,transform_train_x_dtype=torch.float16))

model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2:ResNet
model2.load_state_dict(model.state_dict())
quantize_(model2, Int4WeightOnlyConfig())
print(evaluate(model2,val_loader,criterion,DEVICE,transform_train_x_dtype=torch.float16))

model2 = ResNet(BasicBlock, [3, 3, 3], skip_kaiming_init=True)
inject_scale_layers(model2,[])
model2 = model2.to(DEVICE)
model2 = torch.compile(model2)
model2:ResNet
model2.load_state_dict(model.state_dict())
quant_config = IntxWeightOnlyConfig(weight_dtype=torch.int2)
quantize_(model2, quant_config)
print(evaluate(model2,val_loader,criterion,DEVICE,transform_train_x_dtype=torch.float16))
